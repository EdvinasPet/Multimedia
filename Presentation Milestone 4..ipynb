# %% [markdown]
# # Bit-Rate control Presentation
#
# ## Group members:
#
# ### Ivan Giacomo Collela
# ### Andrea Fusillo
# ### Davide Chiossi
# ### Edvinas Petravicius

# %% [markdown]
# # 2.1 Estimate the bit-rate in an Internet link

# %% [markdown]
# ### First we run ping using the smallest possible payload that provides RTTs values
#
# min RTT 5.336 ms
#
#
#
#
# ### Second we run ping using the largest possible payload to achieve that the most part of the average RTT
#
# RTTavg =76.444ms
#
#
# ### We use this commands:
#
#
# Tp = RTTmin/2 = 2.668ms
#
# Tt = (RTTmax-2*Tp)/2 = 2.668ms
#
# b = B/Tt = 1842.46KBytes = 14739.68 kbitps

# %% [markdown]
# # 2.3 Which data-ordering performs better

# %% [markdown]
# ![raw.jpg](attachment:raw.jpg)
# ## deflate_raw

# %% [markdown]
# ![serial.jpg](attachment:serial.jpg)
# ## deflate_serial

# %% [markdown]
# ![serial2.jpg](attachment:serial2.jpg)
# ## deflate_serial2

# %% [markdown]
# ![byteplanes2_interladed.jpg](attachment:byteplanes2_interladed.jpg)
# ## deflate_serial2_interlaced

# %% [markdown]
# ![byteplanes3.jpg](attachment:byteplanes3.jpg)
# ## deflate_byteplanes3

# %% [markdown]
# ![byteplanes4.jpg](attachment:byteplanes4.jpg)
# ## deflate_byteplanes4

# %% [markdown]
# ![byteplanes2.jpg](attachment:byteplanes2.jpg)
# ## deflate_byteplanes2 3

# %% [markdown]
# # 2.4 RD (Rate/Distortion) curves

# %% [markdown]
# # BR_Control_no

# %%
import matplotlib.pyplot as plt
x=[104.53,158.36,224.75,318.73,435.86]
y=[0.15,0.08,0.04,0.02,0.01]
plt.plot(x,y)
plt.scatter(x,y)
plt.xlabel("Bit-Rate")
plt.ylabel("Disortion")
plt.show()

# %% [markdown]
# # BR_control_add_lost

# %%
import matplotlib.pyplot as plt
x=[187.13,225.69,303.13]
y=[0.64,0.25,0.07]
plt.plot(x,y)
plt.scatter(x,y)
plt.xlabel("Bit-Rate")
plt.ylabel("Disortion")
plt.show()

# %% [markdown]
# # BR_control_lost

# %%
import matplotlib.pyplot as plt
x=[189.3,228.73,305.13]
y=[0.639,0.258,0.0729]
plt.plot(x,y)
plt.scatter(x,y)
plt.xlabel("Bit-Rate")
plt.ylabel("Disortion")
plt.show()

# %% [markdown]
# # BR_control_conservative

# %%
import matplotlib.pyplot as plt
x=[79.76,147.26,276.3]
y=[0.33,0.12,0.04]
plt.plot(x,y)
plt.scatter(x,y)
plt.xlabel("Bit-Rate")
plt.ylabel("Disortion")
plt.show()
