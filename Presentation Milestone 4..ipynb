# %% [markdown]
# # Bit-Rate control Presentation
#
# ## Group members:
#
# ### Ivan Giacomo Collela
# ### Andrea Fusillo
# ### Davide Chiossi
# ### Edvinas Petravicius

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # 2.1 Estimate the bit-rate in an Internet link

# %% [markdown]
# .

# %% [markdown]
# ### First we run ping using the smallest possible payload that provides RTTs values
#
# min RTT 5.336 ms
#
#
#
#
# ### Second we run ping using the largest possible payload to achieve that the most part of the average RTT
#
# RTTavg =76.444ms
#
#
# ### We use this commands:
#
#
# Tp = RTTmin/2 = 2.668ms
#
# Tt = (RTTmax-2*Tp)/2 = 2.668ms
#
# b = B/Tt = 1842.46KBytes = 14739.68 kbitps

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # 2.3 Which data-ordering performs better

# %% [markdown]
# ## deflate_raw
# ![serial.jpg](attachment:serial.jpg)

# %% [markdown]
# ## deflate_serial
# ![raw.jpg](attachment:raw.jpg)

# %% [markdown]
# ## deflate_serial2
# ![serial2.jpg](attachment:serial2.jpg)

# %% [markdown]
# ## deflate_serial2_interlaced
# ![byteplanes2_interladed.jpg](attachment:byteplanes2_interladed.jpg)

# %% [markdown]
# ## deflate_byteplanes3
# ![byteplanes3.jpg](attachment:byteplanes3.jpg)

# %% [markdown]
# ## deflate_byteplanes4
# ![byteplanes4.jpg](attachment:byteplanes4.jpg)

# %% [markdown]
# ## deflate_byteplanes2
# ![byteplanes2.jpg](attachment:byteplanes2.jpg)

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # 2.4 RD (Rate/Distortion) curves

# %% [markdown]
# # BR_control_lost

# %% [markdown]
# # BR_control_conservative

# %% [markdown]
# # Br_control Comparison

# %%
import matplotlib.pyplot as plt
x=[99.73,156.18,224.8,319.16]
y=[0.6,0.379,0.234,0.099,]
x2=[82.55,119.53,154.69,201.32,287.15]
y2=[0.612,0.401,0.246,0.14,0.07]
x3=[82.7,117.65,154.66,200.32,286.29]
y3=[0.639,0.41,0.254,0.13,0.072]
x4=[79.76,103.67,147.26,201.3,276.3]
y4=[0.33,0.20,0.12,0.06,0.04]
plt.plot(x,y, label="no")
plt.scatter(x,y)
plt.plot(x2,y2, label="add_lost")
plt.scatter(x2,y2)
plt.plot(x3,y3, label = "lost")
plt.scatter(x3,y3)
plt.plot(x4,y4, label="conservative")
plt.scatter(x4,y4)
plt.xlabel("Bit-Rate")
plt.ylabel("Disortion")
plt.title("BR_control")
plt.legend()
plt.show()
